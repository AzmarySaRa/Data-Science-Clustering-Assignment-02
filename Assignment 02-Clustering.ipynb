# %% [markdown]
#                                      Mst.Arifa Azmary
#                                      ID:1901006

# %% [markdown]
#                                              PART (A)
# K-means Clustering: In this part, you will be utilizing K-means clustering algorithm to
# identify the appropriate number of clusters. You may use any language and libraries to
# implement K-mean clustering algorithm. Your K-mean clustering algorithm should look for
# appropriate values of K at least in the range of 0 to 15 and show their corresponding sumof-squared errors (SSE).

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import warnings

# %%
# %matplotlib inline

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# statistical info
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
# datatype info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# # Exploratory Data Analysis

# %%
# !pip install --upgrade seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in c:\users\usere\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: matplotlib in c:\users\usere\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\usere\anaconda3\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\usere\anaconda3\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\usere\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usere\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2022.7)
# Requirement already satisfied: six>=1.5 in c:\users\usere\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the count plot
sns.countplot(data=df, x='Gender')

# Label the axes
plt.xlabel('Gender')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
sns.distplot(df['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Density'>

# %% [markdown]
# # Correlation Matrix

# %%
numerical_columns = df.select_dtypes(include=['number'])
corr = numerical_columns.corr()
sns.heatmap(corr, annot=True, cmap='cividis')  # Using the 'cividis' colormap
# Out:
# <Axes: >

# %% [markdown]
# # Clustering

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# cluster on 2 features
df1 = df[['Annual Income (k$)', 'Spending Score (1-100)']]
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
# scatter plot
sns.scatterplot(x=df1['Annual Income (k$)'], y=df1['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
from sklearn.cluster import KMeans
errors = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df1)
    errors.append(kmeans.inertia_)

# %%
# plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11), errors)
plt.plot(range(1,11), errors, linewidth=3, color='red', marker='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
km = KMeans(n_clusters=5)
km.fit(df1)
y = km.predict(df1)
df1['Label'] = y
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Label
# 0                  15                      39      3
# 1                  15                      81      2
# 2                  16                       6      3
# 3                  16                      77      2
# 4                  17                      40      3

# %%
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df1, hue='Label', s=50, palette=['crimson', 'lime', 'sienna', 'royalblue', 'coral'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
# cluster on 3 features
df2 = df[['Annual Income (k$)', 'Spending Score (1-100)', 'Age']]
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age
# 0                  15                      39   19
# 1                  15                      81   21
# 2                  16                       6   20
# 3                  16                      77   23
# 4                  17                      40   31

# %%
errors = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(df2)
    errors.append(kmeans.inertia_)

# %%
# plot the results for elbow method
plt.figure(figsize=(13,6))
plt.plot(range(1,11), errors)
plt.plot(range(1,11), errors, linewidth=3, color='red', marker='8')
plt.xlabel('No. of clusters')
plt.ylabel('WCSS')
plt.xticks(np.arange(1,11,1))
plt.show()

# %%
km = KMeans(n_clusters=5)
km.fit(df2)
y = km.predict(df2)
df2['Label'] = y
df2.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Age  Label
# 0                  15                      39   19      4
# 1                  15                      81   21      2
# 2                  16                       6   20      4
# 3                  16                      77   23      2
# 4                  17                      40   31      4

# %%
# 3d scatter plot
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df2['Age'][df2['Label']==0], df2['Annual Income (k$)'][df2['Label']==0], df2['Spending Score (1-100)'][df2['Label']==0], c='red', s=50)
ax.scatter(df2['Age'][df2['Label']==1], df2['Annual Income (k$)'][df2['Label']==1], df2['Spending Score (1-100)'][df2['Label']==1], c='green', s=50)
ax.scatter(df2['Age'][df2['Label']==2], df2['Annual Income (k$)'][df2['Label']==2], df2['Spending Score (1-100)'][df2['Label']==2], c='blue', s=50)
ax.scatter(df2['Age'][df2['Label']==3], df2['Annual Income (k$)'][df2['Label']==3], df2['Spending Score (1-100)'][df2['Label']==3], c='brown', s=50)
ax.scatter(df2['Age'][df2['Label']==4], df2['Annual Income (k$)'][df2['Label']==4], df2['Spending Score (1-100)'][df2['Label']==4], c='orange', s=50)
ax.view_init(30, 190)
ax.set_xlabel('Age')
ax.set_ylabel('Annual Income')
ax.set_zlabel('Spending Score')
plt.show()

# %% [markdown]
#                                                 PART (B)
#
# Hierarchical Clustering: In this part, you will apply hierarchical clustering algorithm (agglomerative or divisive) to the provided mall dataset.

# %% [markdown]
# # Clustering on Mall_Customers Dataset

# %% [markdown]
# # Data Overview

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

dataset = pd.read_csv("Mall_Customers.csv")
dataset.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
dataset.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# # took two Features to classify customer type.

# %%
X = dataset.iloc[:, 3:]
X.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)
# 0                  15                      39
# 1                  15                      81
# 2                  16                       6
# 3                  16                      77
# 4                  17                      40

# %%
import scipy.cluster.hierarchy as hc
import matplotlib.pyplot as plt
from pylab import rcParams

rcParams['figure.figsize'] = 15, 10

# %%
# Using Dendogram to find the optimal number of clusters
dendogram  = hc.dendrogram(hc.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean Distances')
plt.show()

# %%
dendogram  = hc.dendrogram(hc.linkage(X, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('Customers')
plt.ylabel('Euclidean Distances')
plt.axhline(200, c='r', linestyle='--')
plt.show()

# %%
# Fitting hierarchical clustering to the mall dataset
from sklearn.cluster import AgglomerativeClustering
hc_Agg = AgglomerativeClustering(n_clusters = 5, affinity = 'euclidean', linkage = 'ward')
y_hc = hc_Agg.fit_predict(X)

# %%
# Visualizing the clusters
plt.scatter(X.iloc[y_hc == 0, 0], X.iloc[y_hc == 0, 1], s=100, c='orange', label='Careful')
plt.scatter(X.iloc[y_hc == 1, 0], X.iloc[y_hc == 1, 1], s=100, c='purple', label='Standard')
plt.scatter(X.iloc[y_hc == 2, 0], X.iloc[y_hc == 2, 1], s=100, c='pink', label='Target')
plt.scatter(X.iloc[y_hc == 3, 0], X.iloc[y_hc == 3, 1], s=100, c='green', label='Careless')
plt.scatter(X.iloc[y_hc == 4, 0], X.iloc[y_hc == 4, 1], s=100, c='blue', label='Sensible')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %% [markdown]
#                                                       PART (C)
# Density-based Clustering: In this part, you will apply density-based clustering algorithm to the provided dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
# Load the dataset
data = pd.read_csv("Mall_Customers.csv")
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Extract the relevant features
X = data.iloc[:, [3, 4]].values  # Annual Income and Spending Score

# %%
# Standardize the data 
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
# Create a DBSCAN clustering model
dbscan = DBSCAN(eps=0.5, min_samples=5)

# %%
# Fit the model to the data
clusters = dbscan.fit_predict(X_std)

# %%
# Plot the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X_std[:, 0], X_std[:, 1], c=clusters, cmap='cool')  # Using the 'cool' colormap
plt.title('DBSCAN Clustering')
plt.xlabel('Standardized Annual Income')
plt.ylabel('Standardized Spending Score')
plt.show()
